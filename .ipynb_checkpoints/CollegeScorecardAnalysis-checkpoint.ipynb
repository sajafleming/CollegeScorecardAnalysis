# %%
import pandas as pd
from statsmodels.api import OLS
pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
# %matplotlib inline

import math

import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt
mpl.rcParams["figure.figsize"] = (15, 8)

import us

# %%
college_df = pd.read_csv('..\CollegeScorecard_Raw_Data\CollegeScorecard_Raw_Data\MERGED2012_PP.csv').set_index("INSTNM")
college_df.head()
# Out:
# C:\Users\Dave\Anaconda\lib\site-packages\pandas\io\parsers.py:1170: DtypeWarning: Columns (1427,1517,1532,1542,1545,1546,1575) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)
#                                      ﻿UNITID    OPEID  opeid6        CITY  \
# INSTNM
# Alabama A & M University              100654   100200    1002      Normal
# University of Alabama at Birmingham   100663   105200    1052  Birmingham
# Amridge University                    100690  2503400   25034  Montgomery
# University of Alabama in Huntsville   100706   105500    1055  Huntsville
# Alabama State University              100724   100500    1005  Montgomery
#
#                                     STABBR         ZIP  AccredAgency  INSTURL  \
# INSTNM
# Alabama A & M University                AL       35762           NaN      NaN
# University of Alabama at Birmingham     AL  35294-0110           NaN      NaN
# Amridge University                      AL  36117-3553           NaN      NaN
# University of Alabama in Huntsville     AL       35899           NaN      NaN
# Alabama State University                AL  36104-0271           NaN      NaN
#
#                                      NPCURL  sch_deg         ...          \
# INSTNM                                                       ...
# Alabama A & M University                NaN        3         ...
# University of Alabama at Birmingham     NaN        3         ...
# Amridge University                      NaN        3         ...
# University of Alabama in Huntsville     NaN        3         ...
# Alabama State University                NaN        3         ...
#
#                                      PELL_RPY_3YR_RT_SUPP  \
# INSTNM
# Alabama A & M University                   0.440384615385
# University of Alabama at Birmingham        0.744820616473
# Amridge University                         0.458563535912
# University of Alabama in Huntsville        0.726251276813
# Alabama State University                   0.291703442189
#
#                                      NOPELL_RPY_3YR_RT_SUPP  \
# INSTNM
# Alabama A & M University                     0.435294117647
# University of Alabama at Birmingham          0.814925373134
# Amridge University                           0.605263157895
# University of Alabama in Huntsville          0.842342342342
# Alabama State University                      0.39175257732
#
#                                      FEMALE_RPY_3YR_RT_SUPP  \
# INSTNM
# Alabama A & M University                     0.469199178645
# University of Alabama at Birmingham           0.78531598513
# Amridge University                           0.465277777778
# University of Alabama in Huntsville          0.778034682081
# Alabama State University                      0.33665480427
#
#                                      MALE_RPY_3YR_RT_SUPP  \
# INSTNM
# Alabama A & M University                    0.40465631929
# University of Alabama at Birmingham        0.749778956676
# Amridge University                         0.544642857143
# University of Alabama in Huntsville        0.767926988266
# Alabama State University                   0.272277227723
#
#                                      FIRSTGEN_RPY_3YR_RT_SUPP  \
# INSTNM
# Alabama A & M University                       0.458398744113
# University of Alabama at Birmingham            0.760399334443
# Amridge University                                      0.496
# University of Alabama in Huntsville            0.770916334661
# Alabama State University                       0.279705573081
#
#                                      NOTFIRSTGEN_RPY_3YR_RT_SUPP  \
# INSTNM
# Alabama A & M University                          0.418864097363
# University of Alabama at Birmingham               0.786069651741
# Amridge University                                0.514851485149
# University of Alabama in Huntsville               0.785009861933
# Alabama State University                          0.310344827586
#
#                                      C150_L4_POOLED_SUPP  C150_4_POOLED_SUPP  \
# INSTNM
# Alabama A & M University                             NaN                 NaN
# University of Alabama at Birmingham                  NaN                 NaN
# Amridge University                                   NaN                 NaN
# University of Alabama in Huntsville                  NaN                 NaN
# Alabama State University                             NaN                 NaN
#
#                                      C200_L4_POOLED_SUPP  C200_4_POOLED_SUPP
# INSTNM
# Alabama A & M University                             NaN                 NaN
# University of Alabama at Birmingham                  NaN                 NaN
# Amridge University                                   NaN                 NaN
# University of Alabama in Huntsville                  NaN                 NaN
# Alabama State University                             NaN                 NaN
#
# [5 rows x 1728 columns]

# %%
college_df[['C150_4']].head()
# Out:
#                                      C150_4
# INSTNM
# Alabama A & M University             0.3222
# University of Alabama at Birmingham  0.4815
# Amridge University                   0.0000
# University of Alabama in Huntsville  0.4732
# Alabama State University             0.2635

# %%
states_str = '''AK, AL, AR, AZ, CA, CO, CT, DC, DE, FL, GA, HI, IA, ID, IL, IN, KS, KY, LA, MA, MD, ME, MI, MN, MO, MS, MT, NC, ND, NE, NH, NJ, NM, NV, NY, OH, OK, OR, PA, RI, SC, SD, TN, TX, UT, VA, VT, WA, WI, WV, WY'''
states = states_str.split(', ')
print states
len(states)
# Out:
# ['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY']
# 51

# %%
completion_by_state_df = college_df[college_df.STABBR.isin(states)][['C150_4', 'STABBR']].groupby('STABBR').mean()
completion_by_state_df
# Out:
#           C150_4
# STABBR
# AK      0.337817
# AL      0.386178
# AR      0.376372
# AZ      0.421642
# CA      0.538709
# CO      0.360851
# CT      0.561186
# DC      0.496808
# DE      0.491850
# FL      0.426888
# GA      0.354258
# HI      0.362733
# IA      0.550536
# ID      0.429800
# IL      0.498627
# IN      0.477025
# KS      0.437553
# KY      0.432861
# LA      0.398023
# MA      0.600650
# MD      0.493579
# ME      0.512505
# MI      0.419753
# MN      0.518129
# MO      0.477731
# MS      0.467250
# MT      0.437140
# NC      0.453413
# ND      0.371220
# NE      0.480008
# NH      0.557869
# NJ      0.497487
# NM      0.337517
# NV      0.295664
# NY      0.518604
# OH      0.445851
# OK      0.333228
# OR      0.524003
# PA      0.593488
# RI      0.688810
# SC      0.478442
# SD      0.383094
# TN      0.439652
# TX      0.427799
# UT      0.467309
# VA      0.472388
# VT      0.504237
# WA      0.473602
# WI      0.487187
# WV      0.402274
# WY      0.336800

# %%
len(completion_by_state_df.index)
# Out:
# 51

# %%
from mpl_toolkits.basemap import Basemap as Basemap
from matplotlib.colors import rgb2hex
from matplotlib.patches import Polygon

# the below is copied from https://github.com/matplotlib/basemap/blob/master/examples/fillstates.py
# Lambert Conformal map of lower 48 states.
m = Basemap(llcrnrlon=-119,llcrnrlat=22,urcrnrlon=-64,urcrnrlat=49,
            projection='lcc',lat_1=33,lat_2=45,lon_0=-95)
# draw state boundaries.
shp_info = m.readshapefile('st99_d00','states',drawbounds=True)

# %%
# choose a color for each state based on completion rate
colors={}
statenames=[]
cmap = plt.cm.hot # use 'hot' colormap
vmin = 0; vmax = 1 # set range.
for shapedict in m.states_info:
    statename = shapedict['NAME']
    # skip Puerto Rico 
    if statename not in ['Puerto Rico']:
        try:
            completion_rate = completion_by_state_df.loc[us.states.lookup(unicode(statename)).abbr]['C150_4']
        except:
            print(statename)
        # calling colormap with value between 0 and 1 returns
        # rgba value.  Invert color range (hot colors are high
        # completion rate), take sqrt root to spread out colors more.
        colors[statename] = cmap(1.-np.sqrt((completion_rate-vmin)/(vmax-vmin)))[:3]
    statenames.append(statename)
# Out:
# Utah

# %%
us.states.lookup('UT')
# Out:
# <State:Utah>
